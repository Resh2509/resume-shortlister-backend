# %%
# !pip install -r requirements.txt
# !python -m spacy download en_core_web_sm
# Out:
# ...
#   Using cached pymupdf-1.26.7-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# ...
# Using cached pymupdf-1.26.7-cp310-abi3-win_amd64.whl (18.4 MB)
# ...

# %%
# !python src/model_training.py --train_csv "data/training_data(1)(1).csv" --out_dir models
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\src\model_training.py", line 14, in <module>
#     from .text_cleaner import clean_text
# ImportError: attempted relative import with no known parent package

# %%
# !python -m src.model_training --train_csv "data/training_data(1)(1).csv" --out_dir models
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\User\ResumeShortlisterML\src\model_training.py", line 14, in <module>
#     from .text_cleaner import clean_text
# ModuleNotFoundError: No module named 'src.text_cleaner'

# %%
import sys
sys.path.append(".")

# %%
# !python src/model_training.py --train_csv "data/training_data(1)(1).csv" --out_dir models
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\src\model_training.py", line 14, in <module>
#     from src.text_cleaner import clean_text
# ModuleNotFoundError: No module named 'src'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\ResumeShortlisterML'

# %%
import sys
sys.path.insert(0, os.getcwd())

# %%
# !python -m src.model_training --train_csv "data/training_data(1)(1).csv" --out_dir models
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
import os
os.listdir("data")
# Out:
# ['Honey_Brittney_Resume (1).pdf',
#  'Mani_Data_Analyst_Resume.pdf',
#  'Reena_Web_Developer_Resume.pdf',
#  'Sheeba_Full_Stack_Developer_Resume.pdf',
#  'training_data (1) (1).csv']

# %%
# !python -m src.model_training --train_csv "data/training_data (1) (1).csv" --out_dir models
# Out:
# Generating BERT embeddings...
# Accuracy: 0.9
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.90        10
#    macro avg       0.90      0.92      0.90        10
# weighted avg       0.92      0.90      0.90        10
#
# Saved BERT + SVM model to models/svm_bert.pkl

# %%
import os
os.listdir("models")
# Out:
# ['scaler.pkl', 'svm_bert.pkl']

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# python: can't open file 'C:\\Users\\User\\ResumeShortlisterML\\main.py': [Errno 2] No such file or directory

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# python: can't open file 'C:\\Users\\User\\ResumeShortlisterML\\main.py': [Errno 2] No such file or directory

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 11, in <module>
#     from src.keyword_extractor import extract_keywords_from_jd
# ImportError: cannot import name 'extract_keywords_from_jd' from 'src.keyword_extractor' (C:\Users\User\ResumeShortlisterML\src\keyword_extractor.py)

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 12, in <module>
#     from src.ats_scoring import compute_ats_score
#   File "C:\Users\User\ResumeShortlisterML\src\ats_scoring.py", line 4, in <module>
#     from .keyword_extractor import normalize_keywords
# ImportError: cannot import name 'normalize_keywords' from 'src.keyword_extractor' (C:\Users\User\ResumeShortlisterML\src\keyword_extractor.py)

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 15, in <module>
#     from src.skill_ranker import rank_skills
# ImportError: cannot import name 'rank_skills' from 'src.skill_ranker' (C:\Users\User\ResumeShortlisterML\src\skill_ranker.py)

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 16, in <module>
#     from src.project_relevance import project_relevance_score
# ImportError: cannot import name 'project_relevance_score' from 'src.project_relevance' (C:\Users\User\ResumeShortlisterML\src\project_relevance.py). Did you mean: 'project_relevance'?

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 17, in <module>
#     from src.quality_scorer import quality_score
# ImportError: cannot import name 'quality_score' from 'src.quality_scorer' (C:\Users\User\ResumeShortlisterML\src\quality_scorer.py). Did you mean: 'quality_scorer'?

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 3, in <module>
#     from src.predictor import ResumePredictor
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 18, in <module>
#     from src.semantic_matcher import embed, cosine_sim
# ImportError: cannot import name 'embed' from 'src.semantic_matcher' (C:\Users\User\ResumeShortlisterML\src\semantic_matcher.py)

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 13, in <module>
#     rp = ResumePredictor(args.pipeline)
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 38, in __init__
#     raise FileNotFoundError("Model not found. Train first.")
# FileNotFoundError: Model not found. Train first.

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 25, in <module>
#     main()
#     ~~~~^^
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 17, in main
#     result = rp.predict_from_pdf(
#         pdf_path=args.pdf,
#         job_description=args.jd
#     )
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 74, in predict_from_pdf
#     ats = compute_ats_score(cleaned, jd_keywords) if job_description else {'score': None, 'matched': [], 'missing': []}
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\ResumeShortlisterML\src\ats_scoring.py", line 11, in compute_ats_score
#     matched = sorted(list(jd_set & resume_tokens))
#                           ~~~~~~~^~~~~~~~~~~~~~~
# TypeError: unsupported operand type(s) for &: 'list' and 'set'

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 25, in <module>
#     main()
#     ~~~~^^
#   File "C:\Users\User\ResumeShortlisterML\main.py", line 17, in main
#     result = rp.predict_from_pdf(
#         pdf_path=args.pdf,
#         job_description=args.jd
#     )
#   File "C:\Users\User\ResumeShortlisterML\src\predictor.py", line 74, in predict_from_pdf
#     ats = compute_ats_score(cleaned, jd_keywords) if job_description else {'score': None, 'matched': [], 'missing': []}
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\ResumeShortlisterML\src\ats_scoring.py", line 11, in compute_ats_score
#     matched = sorted(list(jd_set & set(resume_tokens)))
#                           ~~~~~~~^~~~~~~~~~~~~~~~~~~~
# TypeError: unsupported operand type(s) for &: 'list' and 'set'

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
# !python main.py --pdf "data/Mani_Data_Analyst_Resume.pdf" --jd "Data analyst with Python, SQL, Power BI"
# Out:
# {'pred_label': 1, 'pred_proba': 0.6920318875101553, 'ats': {'score': 100.0, 'matched': ['analyst', 'bi', 'datum', 'power', 'python', 'sql'], 'missing': []}, 'extracted_text_sample': 'mani data analyst chennai tamil nadu phone xxxxxxxx email professional summary detail orient data analyst strong analytical problem solve skill experience analyze dataset create dashboard generate insight excel power bi python sql education bachelor technology tech computer science engineering cse xyz engineering college year graduation 20xx technical skill cid 127 tool excel power bi google sheet cid 127 programming python panda numpy sql cid 127 concept datum clean datum visualization exploratory datum analysis cid 127 soft skill communication analytical thinking problem solve experience datum analyst intern abc technology cid 127 analyze dataset identify trend pattern cid 127 clean transform raw datum report cid 127 build interactive dashboard power bi project sale performance analysis analyze sale da
# ...

# %%
# !python main.py --pdf "data/Reena_Web_Developer_Resume.pdf" --jd "Web developer with HTML, CSS, JavaScript, React, Python"
# Out:
# {'pred_label': 1, 'pred_proba': 0.6884780825094989, 'ats': {'score': 100.0, 'matched': ['css', 'developer', 'html', 'javascript', 'python', 'react', 'web'], 'missing': []}, 'extracted_text_sample': 'reena web developer phone location india professional summary creative detail orient web developer strong foundation design develop responsive website skilled end basic end technology hand experience academic practical project education bachelor technology tech information technology year graduation 20xx technical skill cid 127 end html css javascript bootstrap cid 127 end python basic php basic cid 127 framework react basic cid 127 tool vs code git github cid 127 concept responsive design web host basic experience web development intern cid 127 develop responsive web page html css javascript cid 127 work improve website ui user experience cid 127 assist debug maintain web application project responsive portfolio website design develop personal portfolio website showcasing skill project o
# ...

# %%
# !python main.py --pdf "data/Reena_Web_Developer_Resume.pdf" --jd "Web developer with HTML, CSS, JavaScript, React, Python"
# Out:
# {'pred_label': 1, 'pred_proba': 0.6884780825094989, 'ats': {'score': 100.0, 'matched': ['css', 'developer', 'html', 'javascript', 'python', 'react', 'web'], 'missing': []}, 'extracted_text_sample': 'reena web developer phone location india professional summary creative detail orient web developer strong foundation design develop responsive website skilled end basic end technology hand experience academic practical project education bachelor technology tech information technology year graduation 20xx technical skill cid 127 end html css javascript bootstrap cid 127 end python basic php basic cid 127 framework react basic cid 127 tool vs code git github cid 127 concept responsive design web host basic experience web development intern cid 127 develop responsive web page html css javascript cid 127 work improve website ui user experience cid 127 assist debug maintain web application project responsive portfolio website design develop personal portfolio website showcasing skill project o
# ...
